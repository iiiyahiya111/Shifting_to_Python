# %%
| Method | Description |
|---|---|
| capitalize() | Converts the first character to upper case |
| casefold() | Converts string into lower case (aggressive) |
| center() | Returns a centered string |
| count() | Returns the number of occurrences of a substring |
| encode() | Returns an encoded version of the string |
| endswith() | Returns True if the string ends with the specified value |
| expandtabs() | Sets the tab size of the string |
| find() | Searches for a value and returns the first index (or -1) |
| format() | Formats specified values in a string |
| format_map() | Formats values using a mapping object |
| index() | Searches for a value and returns the first index (raises ValueError if not found) |
| isalnum() | Returns True if all characters are alphanumeric |
| isalpha() | Returns True if all characters are alphabetic |
| isascii() | Returns True if all characters are ASCII |
| isdecimal() | Returns True if all characters are decimal characters |
| isdigit() | Returns True if all characters are digits |
| isidentifier() | Returns True if the string is a valid identifier |
| islower() | Returns True if all cased characters are lowercase |
| isnumeric() | Returns True if all characters are numeric |
| isprintable() | Returns True if all characters are printable |
| isspace() | Returns True if all characters are whitespace |
| istitle() | Returns True if the string is titlecased |
| isupper() | Returns True if all cased characters are uppercase |
| join() | Joins the elements of an iterable into the string |
| ljust() | Returns a left-justified string |
| lower() | Converts the string to lowercase |
| lstrip() | Removes leading whitespace (or specified chars) |
| maketrans() | Returns a translation table for translate() |
| partition() | Splits the string at the first occurrence into a 3-tuple |
| replace() | Returns a string with specified replacements |
| rfind() | Searches for a value and returns the last index (or -1) |
| rindex() | Searches for a value and returns the last index (raises ValueError if not found) |
| rjust() | Returns a right-justified string |
| rpartition() | Splits the string at the last occurrence into a 3-tuple |
| rsplit() | Splits the string from the right and returns a list |
| rstrip() | Removes trailing whitespace (or specified chars) |
| split() | Splits the string at the specified separator and returns a list |
| splitlines() | Splits at line boundaries and returns a list |
| startswith() | Returns True if the string starts with the specified value |
| strip() | Removes leading and trailing whitespace (or specified chars) |
| swapcase() | Swaps case: lower becomes upper and vice versa |
| title() | Converts the first character of each word to uppercase |
| translate() | Returns a translated string using a translation table |
| upper() | Converts the string to uppercase |
| zfill() | Pads the string on the left with zeros to fill a width |
