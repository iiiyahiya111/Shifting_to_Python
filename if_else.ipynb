# %% [markdown]
# If else Condition

# %%
a=2

if a>5:
    print("a is not less than 5")
else:
    print("a is not greater than 5")
# Out:
# a is not greater than 5
# asdf

# %%
a=int(input("Are u student(1/0): "))
if a==1:
    b=int(input("Your Age : "))
    if b>20:
        print(f"Your are a Student, Your age is {b}")
    else:
        print("age less than 20")
else:
    print("not student")
# Out:
# age less than 20
