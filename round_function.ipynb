# %%
a=3.454567
print(round(a,2))
print(round(a,3))
print(round(a)) #return integer
# Out:
# 3.45
# 3.455
# 3

# %%
a=634.33
print(f"{a} rounded by 2, then: {round(a,2)}")
print(f"{a} rounded by -1, then: {round(a,-1)}")

aa=854.34
print(f"{aa} rounded by -2, then: {round(aa,-2)}")


b=40.6
c=40.4
print(f"{b} rounded by 0, then: {round(b)}")
print(f"{c} rounded by 0, then: {round(c)}")
# Out:
# 634.33 rounded by 2, then: 634.33
# 634.33 rounded by -1, then: 630.0
# 854.34 rounded by -2, then: 900.0
# 40.6 rounded by 0, then: 41
# 40.4 rounded by 0, then: 40
