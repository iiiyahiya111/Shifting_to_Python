# %% [markdown]
# Tupple - in python tupple is imutable

# %%
num=(1,2,3,4)
cha=("yahiya","abid","barakat")
mix=("khan",3,True,3.4)

print(mix)
# Out:
# ('khan', 3, True, 3.4)

# %% [markdown]
# Invalid Tupple

# %%
t=(10) #invalid tupple, it acts as integer
t1=(10,) #valid

print(type(t))
print(type(t1))
# Out:
# <class 'int'>
# <class 'tuple'>

# %% [markdown]
# Reverse print of tuple

# %%
a=(1,2,3,4)
print(a[::-1])
# Out:
# (4, 3, 2, 1)

# %% [markdown]
# Merge

# %%
t1=("a",1,2)
t2=("b",9,8)
t3=(t1,t2)

print(t3)
# Out:
# (('a', 1, 2), ('b', 9, 8))

# %%
print(len(t3))
print(t3[0])
# Out:
# 2
# ('a', 1, 2)
