# %%
a=input("Enter name1 : ")
b=input("Enter name2 : ")

comb=a+b
ab=comb.lower()

#true love
t=ab.count('t')
r=ab.count('r')
u=ab.count('u')
e=ab.count('e')

l=ab.count('l')
o=ab.count('o')
v=ab.count('v')
e=ab.count('e')

a1=str(t+r+u+e)
a2=str(l+o+v+e)
print(a1+a2)
# Out:
# 23
