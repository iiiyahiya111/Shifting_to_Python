# %% [markdown]
# **Bitwise Operator**

# %%
a=5
b=4

# %%
print(a & b)
# Out:
# 4

# %%
print(a | b)
# Out:
# 5

# %%
print(~a)
# Out:
# -6

# %%
print(a<<2)
# Out:
# 20

# %%
print(a>>2)
# Out:
# 1
