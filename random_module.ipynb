# %%
import random

a=random.randrange(1,4) #exclude 4
#a=random.randint(1,4) #include 4
print(a)
print()

b=random.random() 
print(b)

c=random.uniform(1,3)
print(c)
# Out:
# 1
#
# 0.7588861831144185
# 1.2554996661022526

# %%
l=[1,4,8,0,12,78,91]
a=random.choice(l)
print(a)
# Out:
# 0

# %%
l=[1,4,8,0,12,78,91]
random.shuffle(l)
print(l)
# Out:
# [78, 4, 0, 12, 1, 8, 91]
