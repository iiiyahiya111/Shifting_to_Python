# %%
l=[1,2,3,4,5]
for i in l:
    print(i,end=" ")
else:
    print()
    print("List is completed")
# Out:
# 1 2 3 4 5
# List is completed

# %%
for i in range(0,-5,-1):
    print(i)
# Out:
# 0
# -1
# -2
# -3
# -4
