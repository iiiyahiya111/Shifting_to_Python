# %% [markdown]
# Nested List

# %%
l=[1,2,3,[11,22,33],5]
print(l)
print(l[3])
# Out:
# [1, 2, 3, [11, 22, 33], 5]
# [11, 22, 33]

# %%
print(l[3])
print(l[3][0])
print(l[3][1])
print(l[3][2])
# Out:
# [11, 22, 33]
# 11
# 22
# 33
